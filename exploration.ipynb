# %%
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
from io import BytesIO

# %%
validation = "/Users/jon/Documents/FYP/OCR Data/data/validation-00000-of-00001-d4437dd0d8db37e8.parquet"
train = "/Users/jon/Documents/FYP/OCR Data/data/train-00000-of-00001-82ad548e2f991d3f.parquet"
test_path = "data/test-00000-of-00001-ee77053d3fbe2ea5.parquet"
df_validation = pd.read_parquet(validation)
df_train = pd.read_parquet(train)
df_test = pd.read_parquet(test_path)

# %%
print(df_validation.shape)
print(df_train.shape)
print(df_test.shape)
# Out:
# (272, 3)
# (1897, 3)
# (543, 3)

# %%
df_train.iloc[0]
# Out:
# Identifier                     UM-1963-08-20-01-10-Column-46-10
# Image         {'bytes': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x...
# Text                                     تيدق لاهير، مک ککاچوان
# Name: 0, dtype: object

# %%
def display_image(bytes_data):
    image = Image.open(BytesIO(bytes_data))
    plt.imshow(image)
    plt.axis('off')
    plt.show()

# %%
display_image(df.iloc[0][1]['bytes'])
# Out:
# /var/folders/ss/pdkk1rbd1031gm3qppsr1_gh0000gn/T/ipykernel_92645/1825871080.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   display_image(df.iloc[0][1]['bytes'])
